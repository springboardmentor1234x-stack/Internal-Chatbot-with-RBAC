# %% [markdown]
# <a href="https://colab.research.google.com/github/Lalasa-web/Fintech-data/blob/main/Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# !ls /content/gdrive/MyDrive/gitdemo/
# Out:
# Fintech-data  LocalRepo  sample-project-demo

# %%
# %cd /content/gdrive/MyDrive/gitdemo/
# Out:
# /content/gdrive/MyDrive/gitdemo

# %%
# !ls /content/gdrive/MyDrive/gitdemo/Fintech-data/Finance
# Out:
# er  financial_summary.md  quarterly_financial_report.md  script.py

# %%
# %cd /content/gdrive/MyDrive/gitdemo/Fintech-data/Finance
# Out:
# /content/gdrive/MyDrive/gitdemo/Fintech-data/Finance

# %%
from pathlib import Path
from typing import List, Dict

def tokenize_text(text: str) -> List[str]:
    return text.split()

def chunk_by_token_limit(tokens: List[str], max_tokens: int = 350, max_chunks: int = 3) -> List[str]:
    chunks = []

    for i in range(0, min(len(tokens), max_tokens * max_chunks), max_tokens):
        chunk_tokens = tokens[i:i + max_tokens]
        chunk_text = " ".join(chunk_tokens)
        chunks.append(chunk_text)

        if len(chunks) == max_chunks:
            break

    return chunks

def generate_metadata(chunk: str, file_name: str, department: str, role: str, chunk_id: int) -> Dict:
    return {
        "chunk_id": chunk_id,
        "file_name": file_name,
        "department": department,
        "role": role,
        "source_type": "md",
        "token_count": len(chunk.split()),
        "text_preview": chunk[:120] + "..."
    }

def process_document(file_path: Path, department: str, role: str):
    text = file_path.read_text(encoding="utf-8")

    tokens = tokenize_text(text)
    chunks = chunk_by_token_limit(tokens, max_tokens=350, max_chunks=3)

    metadata_records = []
    for i, chunk in enumerate(chunks, start=1):
        meta = generate_metadata(
            chunk=chunk,
            file_name=file_path.name,
            department=department,
            role=role,
            chunk_id=i
        )
        metadata_records.append(meta)

    return chunks, metadata_records


doc = Path("/content/gdrive/MyDrive/gitdemo/Fintech-data/Finance/financial_summary.md")


if not doc.exists():
    raise FileNotFoundError(f"File not found at: {doc}")

chunks, metadata = process_document(
    file_path=doc,
    department="finance",
    role="manager"
)

print("\n TOTAL CHUNKS CREATED:", len(chunks))

for i, c in enumerate(chunks, start=1):
    print(f"\n--- CHUNK {i} | Tokens: {len(c.split())} ---\n")
    print(c[:700], "...\n")

print("\n\n --- GENERATED METADATA ---\n")
for m in metadata:
    print(m)
# Out:
#  TOTAL CHUNKS CREATED: 3
#
# --- CHUNK 1 | Tokens: 350 ---
#
# # Financial Report for FinSolve Technologies Inc. - 2024 Executive Summary: ------------------------------------------- 2024 marked a year of both opportunity and challenge for FinSolve Technologies. Despite a robust revenue increase, we saw significant pressure in certain expense categories, notably vendor-related costs and software subscriptions. However, these pressures were balanced by cost-saving measures in operational efficiency, strong gross margin performance, and strategic investment in growth areas. The company is well-positioned to continue scaling its core offerings, but focused attention on cost optimization will be essential for maintaining profitability in the coming years. Y ...
#
#
# --- CHUNK 2 | Tokens: 350 ---
#
# ...
